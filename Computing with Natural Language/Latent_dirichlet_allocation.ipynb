# %% [markdown]
# ## Step 0: Latent Dirichlet Allocation ##
#
# LDA is used to classify text in a document to a particular topic. It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.
#
# * Each document is modeled as a multinomial distribution of topics and each topic is modeled as a multinomial distribution of words.
# * LDA assumes that the every chunk of text we feed into it will contain words that are somehow related. Therefore choosing the right corpus of data is crucial.
# * It also assumes documents are produced from a mixture of topics. Those topics then generate words based on their probability distribution.

# %% [markdown]
# ## Step 1: Load the dataset
#
# The dataset we'll use is a list of over one million news headlines published over a period of 15 years. We'll start by loading it from the `abcnews-date-text.csv` file.

# %%
'''
Load the dataset from the CSV and save it to 'data_text'
'''
import pandas as pd
data = pd.read_csv('abcnews-date-text.csv', error_bad_lines=False);
# We only need the Headlines text column from the data
data_text = data[:300000][['headline_text']];
data_text['index'] = data_text.index

documents = data_text

# %% [markdown]
# Let's glance at the dataset:

# %%
'''
Get the total number of documents
'''
print(len(documents))
# Out:
# 300000

# %%
documents[:5]
# Out:
#                                        headline_text  index
# 0  aba decides against community broadcasting lic...      0
# 1     act fire witnesses must be aware of defamation      1
# 2     a g calls for infrastructure protection summit      2
# 3           air nz staff in aust strike for pay rise      3
# 4      air nz strike to affect australian travellers      4

# %% [markdown]
# ## Step 2: Data Preprocessing ##
#
# We will perform the following steps:
#
# * **Tokenization**: Split the text into sentences and the sentences into words. Lowercase the words and remove punctuation.
# * Words that have fewer than 3 characters are removed.
# * All **stopwords** are removed.
# * Words are **lemmatized** - words in third person are changed to first person and verbs in past and future tenses are changed into present.
# * Words are **stemmed** - words are reduced to their root form.

# %%
'''
Loading Gensim and nltk libraries
'''
# pip install gensim
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
# Out:
# C:\Users\wc5257\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\wc5257\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Lemmatizer Example
# Before preprocessing our dataset, let's first look at an lemmatizing example. What would be the output if we lemmatized the word 'went':

# %%
print(WordNetLemmatizer().lemmatize('went', pos = 'v')) # past tense to present tense
# Out:
# go

# %% [markdown]
# ### Stemmer Example
# Let's also look at a stemming example. Let's throw a number of words at the stemmer and see how it deals with each one:

# %%
stemmer = SnowballStemmer("english")
original_words = ['caresses', 'flies', 'dies', 'mules', 'denied','died', 'agreed', 'owned', 
           'humbled', 'sized','meeting', 'stating', 'siezing', 'itemization','sensational', 
           'traditional', 'reference', 'colonizer','plotted']
singles = [stemmer.stem(plural) for plural in original_words]

pd.DataFrame(data={'original word':original_words, 'stemmed':singles })
# Out:
#    original word stemmed
# 0       caresses  caress
# 1          flies     fli
# 2           dies     die
# 3          mules    mule
# 4         denied    deni
# 5           died     die
# 6         agreed    agre
# 7          owned     own
# 8        humbled   humbl
# 9          sized    size
# 10       meeting    meet
# 11       stating   state
# 12       siezing    siez
# 13   itemization    item
# 14   sensational  sensat
# 15   traditional  tradit
# 16     reference   refer
# 17     colonizer   colon
# 18       plotted    plot

# %%
'''
Write a function to perform the pre processing steps on the entire dataset
'''
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            # TODO: Apply lemmatize_stemming() on the token, then add to the results list
            result.append(lemmatize_stemming(token))
            
    return result

# %%
'''
Preview a document after preprocessing
'''
document_num = 4310
doc_sample = documents[documents['index'] == document_num].values[0][0]

print("Original document: ")
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and lemmatized document: ")
print(preprocess(doc_sample))
# Out:
# Original document:
# ['rain', 'helps', 'dampen', 'bushfires']
#
#
# Tokenized and lemmatized document:
# ['rain', 'help', 'dampen', 'bushfir']

# %%
documents
# Out:
#                                             headline_text   index
# 0       aba decides against community broadcasting lic...       0
# 1          act fire witnesses must be aware of defamation       1
# 2          a g calls for infrastructure protection summit       2
# 3                air nz staff in aust strike for pay rise       3
# 4           air nz strike to affect australian travellers       4
# ...                                                   ...     ...
# 299995      broughton hall audit reveals serious breaches  299995
# 299996                 broughton hall fails key standards  299996
# 299997        broughton hall safe for residents govt says  299997
# 299998      burn off at conservation park aims to prevent  299998
# 299999                      burns suspended for two games  299999
#
# [300000 rows x 2 columns]

# %% [markdown]
# Let's now preprocess all the news headlines we have. To do that, let's use the [map](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) function from pandas to apply `preprocess()` to the `headline_text` column
#
# **Note**: This may take a few minutes (it take 6 minutes on my laptop)

# %%
# TODO: preprocess all the headlines, saving the list of results as 'processed_docs'
# when using map, send the function but without the ()
processed_docs = documents['headline_text'].map(preprocess)

# %%
'''
Preview 'processed_docs'
'''
processed_docs[:10]
# Out:
# 0            [decid, communiti, broadcast, licenc]
# 1                               [wit, awar, defam]
# 2           [call, infrastructur, protect, summit]
# 3                      [staff, aust, strike, rise]
# 4             [strike, affect, australian, travel]
# 5               [ambiti, olsson, win, tripl, jump]
# 6           [antic, delight, record, break, barca]
# 7    [aussi, qualifi, stosur, wast, memphi, match]
# 8            [aust, address, secur, council, iraq]
# 9                         [australia, lock, timet]
# Name: headline_text, dtype: object

# %% [markdown]
# ## Step 3.1: Bag of words on the dataset
#
# Now let's create a dictionary from 'processed_docs' containing the number of times a word appears in the training set. To do that, let's pass `processed_docs` to [`gensim.corpora.Dictionary()`](https://radimrehurek.com/gensim/corpora/dictionary.html) and call it '`dictionary`'.

# %%
'''
Create a dictionary from 'processed_docs' containing the number of times a word appears 
in the training set using gensim.corpora.Dictionary and call it 'dictionary'
'''
# This module implements the concept of a Dictionary – a mapping between words and their integer ids.
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
'''
Checking dictionary created
'''
# dict of (int, str) -> (token id, word)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 broadcast
# 1 communiti
# 2 decid
# 3 licenc
# 4 awar
# 5 defam
# 6 wit
# 7 call
# 8 infrastructur
# 9 protect
# 10 summit
# 11 aust
# 12 rise
# 13 staff
# 14 strike
# 15 affect
# 16 australian
# 17 travel
# 18 jump
# 19 tripl
# 20 win
# 21 antic
# 22 barca
# 23 break
# 24 delight
# 25 record
# 26 aussi
# 27 match
# 28 memphi
# 29 qualifi
# 30 stosur
# 31 wast
# 32 address
# 33 council
# 34 iraq
# 35 secur
# 36 australia
# 37 lock
# 38 timet
# 39 contribut
# 40 million
# 41 birthday
# 42 celebr
# 43 robson
# 44 ahead
# 45 plan
# 46 championship
# 47 cycl
# 48 hop
# 49 launceston
# 50 boost
# 51 suppli
# 52 water
# 53 bill
# 54 buri
# 55 state
# 56 unit
# 57 dismiss
# 58 harass
# 59 report
# 60 troop
# 61 arriv
# 62 british
# 63 combat
# 64 daili
# 65 kuwait
# 66 bryant
# 67 doubl
# 68 laker
# 69 lead
# 70 overtim
# 71 bushfir
# 72 centrelink
# 73 urg
# 74 victim
# 75 attack
# 76 busi
# 77 prepar
# 78 terrorist
# 79 aveng
# 80 defeat
# 81 elimin
# 82 final
# 83 blend
# 84 ethanol
# 85 fuel
# 86 freak
# 87 goal
# 88 leav
# 89 roma
# 90 ruin
# 91 cemeteri
# 92 fund
# 93 miss
# 94 code
# 95 conduct
# 96 donat
# 97 organ
# 98 regul
# 99 toughen
# 100 bank
# 101 commonwealth
# 102 cut
# 103 fix
# 104 home
# 105 loan
# 106 rat
# 107 help
# 108 homeless
# 109 youth
# 110 chief
# 111 execut
# 112 fail
# 113 posit
# 114 contest
# 115 councillor
# 116 independ
# 117 wollongong
# 118 garden
# 119 heritag
# 120 move
# 121 ambul
# 122 decis
# 123 levi
# 124 welcom
# 125 breakthrough
# 126 insur
# 127 crean
# 128 critic
# 129 leadership
# 130 shut
# 131 tell
# 132 expect
# 133 threat
# 134 climb
# 135 continu
# 136 death
# 137 korean
# 138 subway
# 139 toll
# 140 conflict
# 141 hold
# 142 iraqi
# 143 dent
# 144 down
# 145 philippoussi
# 146 thriller
# 147 fate
# 148 learn
# 149 march
# 150 digit
# 151 anger
# 152 direct
# 153 govt
# 154 soldier
# 155 disput
# 156 plant
# 157 process
# 158 veget
# 159 maul
# 160 month
# 161 toddler
# 162 die
# 163 passeng
# 164 phone
# 165 chang
# 166 england
# 167 wale
# 168 chemic
# 169 clean
# 170 cost
# 171 recov
# 172 tri
# 173 build
# 174 express
# 175 livestock
# 176 seek
# 177 introduc
# 178 nation
# 179 acid
# 180 contain
# 181 firefight
# 182 spill
# 183 crash
# 184 head
# 185 highway
# 186 injur
# 187 freedom
# 188 profit
# 189 success
# 190 alloc
# 191 domest
# 192 violenc
# 193 risk
# 194 announc
# 195 bridg
# 196 work
# 197 upgrad
# 198 restor
# 199 accus
# 200 court
# 201 german
# 202 sept
# 203 verdict
# 204 back
# 205 gilchrist
# 206 polici
# 207 rest
# 208 girl
# 209 bilbi
# 210 coast
# 211 gold
# 212 hear
# 213 project
# 214 club
# 215 feel
# 216 golf
# 217 impact
# 218 smoke
# 219 blame
# 220 altern
# 221 green
# 222 offer
# 223 polic
# 224 station
# 225 griffith
# 226 knock
# 227 group
# 228 meet
# 229 north
# 230 rock
# 231 west
# 232 access
# 233 card
# 234 credit
# 235 gain
# 236 hacker
# 237 costa
# 238 hanson
# 239 issu
# 240 come
# 241 harrington
# 242 rare
# 243 health
# 244 minist
# 245 storag
# 246 tissu
# 247 deposit
# 248 heavi
# 249 metal
# 250 near
# 251 survey
# 252 air
# 253 open
# 254 pull
# 255 accident
# 256 find
# 257 inquest
# 258 man
# 259 investig
# 260 underway
# 261 creek
# 262 inspect
# 263 neighbour
# 264 plead
# 265 hous
# 266 rebuild
# 267 white
# 268 arrest
# 269 bomb
# 270 irish
# 271 omagh
# 272 irrig
# 273 manag
# 274 river
# 275 vote
# 276 forc
# 277 gaza
# 278 isra
# 279 push
# 280 strip
# 281 case
# 282 consid
# 283 juri
# 284 murder
# 285 juvenil
# 286 offend
# 287 unlik
# 288 alleg
# 289 disgust
# 290 kelli
# 291 scare
# 292 confid
# 293 surpris
# 294 hand
# 295 minut
# 296 demand
# 297 servic
# 298 attempt
# 299 central
# 300 hijack
# 301 charg
# 302 cooma
# 303 aborigin
# 304 embassi
# 305 fin
# 306 raid
# 307 tent
# 308 fraud
# 309 jail
# 310 knife
# 311 light
# 312 plane
# 313 lobbi
# 314 lose
# 315 martin
# 316 seat
# 317 crop
# 318 discov
# 319 drug
# 320 massiv
# 321 western
# 322 landfil
# 323 mayor
# 324 protest
# 325 warn
# 326 clearanc
# 327 tick
# 328 focus
# 329 hill
# 330 woe
# 331 growth
# 332 lift
# 333 moder
# 334 wag
# 335 alcohol
# 336 drink
# 337 young
# 338 northern
# 339 predict
# 340 restrict
# 341 women
# 342 educ
# 343 high
# 344 live
# 345 concern
# 346 hospit
# 347 parliament
# 348 rais
# 349 claim
# 350 reject
# 351 mugab
# 352 pari
# 353 touch
# 354 clear
# 355 galleri
# 356 get
# 357 defend
# 358 give
# 359 nato
# 360 turkey
# 361 entri
# 362 impos
# 363 visa
# 364 zealand
# 365 zimbabw
# 366 cough
# 367 effect
# 368 vaccin
# 369 whoop
# 370 campaign
# 371 race
# 372 run
# 373 drought
# 374 pledg
# 375 relief
# 376 intak
# 377 number
# 378 nurs
# 379 oversea
# 380 asylum
# 381 japanes
# 382 student
# 383 brother
# 384 ganguli
# 385 say
# 386 senior
# 387 time
# 388 omodei
# 389 polit
# 390 stay
# 391 invest
# 392 onesteel
# 393 steelwork
# 394 whyalla
# 395 opposit
# 396 recherch
# 397 begin
# 398 countri
# 399 cross
# 400 doubt
# 401 world
# 402 necessari
# 403 pagan
# 404 rule
# 405 face
# 406 pair
# 407 attend
# 408 patterson
# 409 arrog
# 410 display
# 411 avoid
# 412 lion
# 413 snub
# 414 agreement
# 415 bring
# 416 peac
# 417 respit
# 418 venezuela
# 419 ajax
# 420 arsenal
# 421 frustrat
# 422 shin
# 423 second
# 424 encourag
# 425 farmer
# 426 plantat
# 427 timber
# 428 colleagu
# 429 rap
# 430 crack
# 431 driver
# 432 safeti
# 433 crime
# 434 featur
# 435 feder
# 436 launch
# 437 probe
# 438 area
# 439 forest
# 440 harvest
# 441 monitor
# 442 program
# 443 check
# 444 public
# 445 scam
# 446 crew
# 447 intern
# 448 qanta
# 449 job
# 450 outrag
# 451 union
# 452 rout
# 453 sack
# 454 grow
# 455 question
# 456 control
# 457 rabbit
# 458 trial
# 459 olymp
# 460 radioact
# 461 eas
# 462 rain
# 463 wheatbelt
# 464 divis
# 465 read
# 466 gladston
# 467 ventur
# 468 refshaug
# 469 canola
# 470 highlight
# 471 potenti
# 472 termin
# 473 ord
# 474 resourc
# 475 stock
# 476 anti
# 477 discrimin
# 478 order
# 479 restraint
# 480 author
# 481 ankl
# 482 ricciuto
# 483 surgeri
# 484 undergo
# 485 closur
# 486 rice
# 487 angri
# 488 bushwalk
# 489 review
# 490 action
# 491 murray
# 492 premier
# 493 qaeda
# 494 saudi
# 495 stand
# 496 arab
# 497 arabia
# 498 inevit
# 499 search
# 500 resolut
# 501 short
# 502 assur
# 503 financ
# 504 shire
# 505 incurs
# 506 kill
# 507 palestinian
# 508 economi
# 509 recoveri
# 510 slow
# 511 ban
# 512 line
# 513 tabcorp
# 514 delay
# 515 snowtown
# 516 label
# 517 shark
# 518 steer
# 519 fisherman
# 520 sign
# 521 fan
# 522 stop
# 523 industri
# 524 reveal
# 525 sugar
# 526 sale
# 527 surg
# 528 challeng
# 529 futur
# 530 look
# 531 swiss
# 532 place
# 533 taipan
# 534 arm
# 535 asian
# 536 downer
# 537 nuclear
# 538 talk
# 539 east
# 540 scientist
# 541 tasmanian
# 542 deni
# 543 quit
# 544 taylor
# 545 waugh
# 546 teen
# 547 show
# 548 standard
# 549 test
# 550 anniversari
# 551 darwin
# 552 rememb
# 553 thousand
# 554 member
# 555 support
# 556 diseas
# 557 studi
# 558 tree
# 559 aircraft
# 560 target
# 561 fee
# 562 local
# 563 poll
# 564 singl
# 565 award
# 566 honour
# 567 victorian
# 568 retir
# 569 season
# 570 coach
# 571 player
# 572 friday
# 573 favourit
# 574 ladi
# 575 master
# 576 webb
# 577 abandon
# 578 paul
# 579 sanctuari
# 580 wildlif
# 581 bowl
# 582 tight
# 583 warrior
# 584 william
# 585 bounc
# 586 wine
# 587 injuri
# 588 potato
# 589 worksaf
# 590 armi
# 591 dead
# 592 philippin
# 593 rebel
# 594 abattoir
# 595 academ
# 596 higher
# 597 upbeat
# 598 administr
# 599 appoint
# 600 land
# 601 declar
# 602 parliamentari
# 603 amcor
# 604 result
# 605 solid
# 606 america
# 607 cancel
# 608 fourth
# 609 beckham
# 610 pois
# 611 swoop
# 612 releas
# 613 soon
# 614 flag
# 615 kembla
# 616 port
# 617 babi
# 618 bad
# 619 brisban
# 620 burn
# 621 caus
# 622 iranian
# 623 weather
# 624 deplet
# 625 juve
# 626 bewar
# 627 dream
# 628 realiti
# 629 britain
# 630 blair
# 631 overturn
# 632 chees
# 633 bungl
# 634 doctor
# 635 practis
# 636 wait
# 637 coroni
# 638 inquiri
# 639 wind
# 640 bush
# 641 thank
# 642 ambo
# 643 wake
# 644 canegrow
# 645 hope
# 646 late
# 647 summer
# 648 capriati
# 649 dubai
# 650 hungri
# 651 celt
# 652 clash
# 653 oneil
# 654 uefa
# 655 underdog
# 656 chamber
# 657 mark
# 658 smash
# 659 vow
# 660 earn
# 661 pay
# 662 penalti
# 663 shock
# 664 centr
# 665 christma
# 666 detent
# 667 quash
# 668 defenc
# 669 prioriti
# 670 spend
# 671 indigen
# 672 autopsi
# 673 consent
# 674 colleg
# 675 experi
# 676 cover
# 677 legal
# 678 canada
# 679 concord
# 680 emerg
# 681 make
# 682 advertis
# 683 lament
# 684 general
# 685 step
# 686 reward
# 687 vandal
# 688 fear
# 689 compo
# 690 longford
# 691 today
# 692 libertador
# 693 streak
# 694 inter
# 695 slam
# 696 buoyant
# 697 deportivo
# 698 minnow
# 699 slip
# 700 distanc
# 701 swimmer
# 702 dixon
# 703 monopoli
# 704 away
# 705 reach
# 706 insect
# 707 take
# 708 childhood
# 709 develop
# 710 earli
# 711 receiv
# 712 research
# 713 elli
# 714 employe
# 715 grant
# 716 restrain
# 717 choke
# 718 king
# 719 morri
# 720 econom
# 721 esso
# 722 loss
# 723 respons
# 724 class
# 725 agre
# 726 fight
# 727 tyson
# 728 confront
# 729 elect
# 730 famili
# 731 presid
# 732 flower
# 733 join
# 734 olonga
# 735 ferguson
# 736 hail
# 737 victori
# 738 fewer
# 739 boss
# 740 fifa
# 741 postpon
# 742 blaze
# 743 facil
# 744 fish
# 745 bundaberg
# 746 flight
# 747 wont
# 748 allianc
# 749 guilti
# 750 theft
# 751 worker
# 752 start
# 753 treasur
# 754 forum
# 755 need
# 756 put
# 757 region
# 758 charter
# 759 nat
# 760 nomin
# 761 preselect
# 762 tower
# 763 drop
# 764 franc
# 765 scot
# 766 expedit
# 767 french
# 768 site
# 769 newcastl
# 770 price
# 771 brom
# 772 fulham
# 773 trio
# 774 india
# 775 gippsland
# 776 guard
# 777 remain
# 778 canvass
# 779 child
# 780 improv
# 781 way
# 782 coron
# 783 suicid
# 784 greenpeac
# 785 dump
# 786 howard
# 787 kit
# 788 terror
# 789 truanci
# 790 agricultur
# 791 outgo
# 792 prais
# 793 reef
# 794 blood
# 795 hagan
# 796 penrith
# 797 rooki
# 798 houllier
# 799 owen
# 800 rush
# 801 score
# 802 crisi
# 803 doesnt
# 804 hussein
# 805 want
# 806 identifi
# 807 illeg
# 808 spot
# 809 draw
# 810 immigr
# 811 melbourn
# 812 includ
# 813 indi
# 814 like
# 815 threaten
# 816 bypass
# 817 stage
# 818 investor
# 819 iran
# 820 militari
# 821 aboard
# 822 human
# 823 shield
# 824 ireland
# 825 itali
# 826 unchang
# 827 boulder
# 828 declin
# 829 kalgoorli
# 830 rate
# 831 adventur
# 832 kayak
# 833 rescu
# 834 formula
# 835 stick
# 836 book
# 837 date
# 838 roddick
# 839 seed
# 840 discuss
# 841 landhold
# 842 allow
# 843 lawyer
# 844 visit
# 845 appeal
# 846 convict
# 847 leas
# 848 lend
# 849 post
# 850 lethal
# 851 point
# 852 accid
# 853 airport
# 854 close
# 855 tunnel
# 856 damag
# 857 kingfish
# 858 macarthur
# 859 minor
# 860 suffer
# 861 apologis
# 862 await
# 863 denmark
# 864 sentenc
# 865 backpack
# 866 incid
# 867 stab
# 868 bail
# 869 refus
# 870 robberi
# 871 thatcher
# 872 effort
# 873 island
# 874 medal
# 875 recognis
# 876 glenelg
# 877 payout
# 878 danger
# 879 zone
# 880 explor
# 881 miner
# 882 nickel
# 883 cocktail
# 884 hotel
# 885 melb
# 886 suspect
# 887 ralli
# 888 noosa
# 889 park
# 890 teacher
# 891 detain
# 892 men
# 893 compromis
# 894 engin
# 895 mosley
# 896 readi
# 897 labor
# 898 motorist
# 899 crab
# 900 ministeri
# 901 wouldnt
# 902 boat
# 903 waterway
# 904 kenya
# 905 thursday
# 906 church
# 907 monument
# 908 coalit
# 909 magic
# 910 benefit
# 911 classic
# 912 holden
# 913 roll
# 914 select
# 915 packer
# 916 pakistani
# 917 disast
# 918 promis
# 919 conserv
# 920 peopl
# 921 pile
# 922 trap
# 923 adelaid
# 924 pilot
# 925 disgrac
# 926 cannabi
# 927 edg
# 928 user
# 929 weapon
# 930 locat
# 2560 madrid
# 2561 disappear
# 2562 fruit
# 2563 request
# 2564 abl
# 2565 kafelnikov
# 2566 resurg
# 2567 rhino
# 2568 nerv
# 2569 overcom
# 2570 log
# 2571 rower
# 2572 erupt
# 2573 activ
# 2574 bare
# 2575 veto
# 2576 pinch
# 2577 roger
# 2578 schole
# 2579 pipelin
# 2580 hervey
# 2581 serena
# 2582 silver
# 2583 middl
# 2584 suncorp
# 2585 policeman
# 2586 viabl
# 2587 tenni
# 2588 panel
# 2589 drum
# 2590 elder
# 2591 chair
# 2592 tablet
# 2593 champ
# 2594 deliber
# 2595 employ
# 2596 deadlock
# 2597 ignor
# 2598 ombudsman
# 2599 vanston
# 2600 wipe
# 2601 algal
# 2602 bloom
# 2603 toxic
# 2604 webber
# 2605 buy
# 2606 insult
# 2607 landmin
# 2608 worldwid
# 2609 dougla
# 2610 ground
# 2611 tokyo
# 2612 amnesti
# 2613 solomon
# 2614 type
# 2615 anglican
# 2616 repres
# 2617 chanc
# 2618 arrow
# 2619 cole
# 2620 mind
# 2621 ceremoni
# 2622 boro
# 2623 viabil
# 2624 atlant
# 2625 controversi
# 2626 bull
# 2627 gabba
# 2628 brutal
# 2629 burundi
# 2630 civil
# 2631 extra
# 2632 mental
# 2633 chechen
# 2634 clijster
# 2635 crazi
# 2636 migrat
# 2637 graham
# 2638 intens
# 2639 dizzi
# 2640 english
# 2641 novak
# 2642 venu
# 2643 colonel
# 2644 russian
# 2645 suprem
# 2646 emot
# 2647 qualiti
# 2648 faster
# 2649 jayasuriya
# 2650 windi
# 2651 john
# 2652 heavyweight
# 2653 hint
# 2654 kean
# 2655 stuart
# 2656 canadian
# 2657 releg
# 2658 reserv
# 2659 derail
# 2660 nice
# 2661 unbeaten
# 2662 rift
# 2663 nuke
# 2664 ogilvi
# 2665 penguin
# 2666 counter
# 2667 pact
# 2668 cellar
# 2669 pig
# 2670 enrol
# 2671 roo
# 2672 mislead
# 2673 maintain
# 2674 lonard
# 2675 sculptur
# 2676 sheffield
# 2677 outdat
# 2678 snow
# 2679 fli
# 2680 huge
# 2681 bite
# 2682 gras
# 2683 mardi
# 2684 parad
# 2685 gear
# 2686 freestyl
# 2687 tobacco
# 2688 anwar
# 2689 egypt
# 2690 annual
# 2691 austria
# 2692 consul
# 2693 policemen
# 2694 generat
# 2695 recess
# 2696 sanction
# 2697 flat
# 2698 downgrad
# 2699 radic
# 2700 lanka
# 2701 chelsea
# 2702 quick
# 2703 postal
# 2704 tamper
# 2705 actu
# 2706 librari
# 2707 mastermind
# 2708 addict
# 2709 seeker
# 2710 add
# 2711 gallipoli
# 2712 pilgrimag
# 2713 rubbish
# 2714 tonn
# 2715 ballack
# 2716 bichel
# 2717 brazilian
# 2718 jumper
# 2719 parachut
# 2720 democraci
# 2721 workforc
# 2722 neglect
# 2723 pitch
# 2724 casa
# 2725 castro
# 2726 moon
# 2727 gazza
# 2728 scottsdal
# 2729 bunni
# 2730 thrash
# 2731 hotlin
# 2732 surround
# 2733 privaci
# 2734 shopper
# 2735 dunde
# 2912 meatwork
# 2913 temporari
# 2914 falter
# 2915 shed
# 2916 feast
# 2917 haven
# 2918 beachley
# 2919 berlin
# 2920 ambit
# 2921 biolog
# 2922 pilbara
# 2923 insid
# 2924 limbo
# 2925 balloon
# 2926 prix
# 2927 brief
# 2928 incom
# 2929 bureau
# 2930 certainti
# 2931 parent
# 2932 holiday
# 2933 adult
# 2934 teach
# 2935 indic
# 2936 oecd
# 2937 true
# 2938 rehab
# 2939 itiner
# 2940 depart
# 2941 winter
# 2942 factor
# 2943 agassi
# 2944 dole
# 2945 jewish
# 2946 februari
# 2947 divorc
# 2948 fals
# 2949 factori
# 2950 belt
# 2951 plummet
# 2952 requir
# 2953 collaps
# 2954 mideast
# 2955 skate
# 2956 latham
# 2957 villa
# 2958 grade
# 2959 manslaught
# 2960 casualti
# 2961 materi
# 2962 print
# 2963 permit
# 2964 jet
# 2965 truth
# 2966 sorri
# 2967 letter
# 2968 squar
# 2969 tiananmen
# 2970 feral
# 2971 bust
# 2972 practic
# 2973 love
# 2974 soar
# 2975 impound
# 2976 cabooltur
# 2977 broom
# 2978 registr
# 2979 longest
# 2980 vic
# 2981 proceed
# 2982 chappel
# 2983 reduc
# 2984 florida
# 2985 slight
# 2986 gympi
# 2987 robert
# 2988 runaway
# 2989 safer
# 2990 sibl
# 2991 mickelson
# 2992 singh
# 2993 steven
# 2994 anxious
# 2995 stewart
# 2996 provinc
# 2997 rattl
# 2998 tremor
# 2999 suspens
# 3000 thirteen
# 3001 sight
# 3002 jakarta
# 3003 psychiatrist
# 3004 tribun
# 3005 boon
# 3006 slice
# 3007 birmingham
# 3008 electrolux
# 3009 medicin
# 3010 subsidi
# 3011 chaplain
# 3012 relax
# 3013 litr
# 3014 liaison
# 3015 aquat
# 3016 architect
# 3017 forward
# 3018 famous
# 3019 arroyo
# 3020 dublin
# 3021 throat
# 3022 lankan
# 3023 spinner
# 3024 sharemarket
# 3025 barrist
# 3026 row
# 3027 wayward
# 3028 depend
# 3029 larger
# 3030 busselton
# 3031 brighter
# 3032 casino
# 3033 carlo
# 3034 germani
# 3035 quiet
# 3036 congress
# 3037 coulthard
# 3038 coastlin
# 3039 entranc
# 3040 renmark
# 3041 window
# 3042 common
# 3043 don
# 3044 pompey
# 3045 gillespi
# 3046 decemb
# 3047 subdu
# 3048 nestl
# 3049 bond
# 3050 reli
# 3051 kashmir
# 3052 devil
# 3053 heaven
# 3054 grower
# 3055 holder
# 3056 builder
# 3057 measur
# 3058 bushrang
# 3059 bow
# 3060 prosper
# 3061 bet
# 3062 hedland
# 3063 reviv
# 3064 nigerian
# 3065 academi
# 3066 trend
# 3067 commod
# 3068 commerc
# 3069 twice
# 3070 evict
# 3071 karratha
# 3072 pharmaci
# 3073 deep
# 3074 space
# 3075 newli
# 3076 complac
# 3077 norway
# 3078 pastoralist
# 3079 shirt
# 3080 strife
# 3081 scar
# 3082 possibl
# 3083 appal
# 3084 document
# 3085 wrangl
# 3086 guarante
# 3087 optimist
# 3088 inmat
# 3089 environment
# 3090 rann
# 3091 remov
# 3092 dirti
# 3093 scud
# 3094 bureaucrat
# 3095 movement
# 3096 sand
# 3097 poppi
# 3098 thoma
# 3099 thrill
# 3100 ocean
# 3101 tide
# 3102 goldfield
# 3103 smaller
# 3104 poet
# 3105 bomber
# 3106 concentr
# 3107 venabl
# 3108 fatigu
# 3109 deepen
# 3110 nimbin
# 3111 fortun
# 3112 armidal
# 3113 wright
# 3114 citizen
# 3115 radio
# 3116 superannu
# 3117 basebal
# 3118 golfer
# 3119 bench
# 3120 rid
# 3121 guitar
# 3122 extent
# 3123 takeov
# 3124 bulldog
# 3125 sustain
# 3126 merci
# 3127 crunch
# 3128 tilt
# 3129 bias
# 3130 psych
# 3131 swarm
# 3132 mentor
# 3133 load
# 3134 incit
# 3135 deadlin
# 3136 serv
# 3137 dili
# 3138 drainag
# 3139 heed
# 3140 cloud
# 3141 alien
# 3142 capitalis
# 3143 rich
# 3144 starv
# 3145 bairnsdal
# 3146 invad
# 3147 secretari
# 3148 tightlip
# 3149 profil
# 3150 blackmail
# 3151 profession
# 3152 retali
# 3153 jewel
# 3154 facelift
# 3155 keelti
# 3156 liabil
# 3157 regatta
# 3158 lithgow
# 3159 junior
# 3160 maradona
# 3161 antarctica
# 3162 conscienc
# 3163 inclus
# 3164 northam
# 3165 unsur
# 3166 kidnapp
# 3167 flop
# 3168 perilya
# 3169 pioneer
# 3170 solo
# 3171 bandit
# 3172 powder
# 3173 compulsori
# 3174 ratepay
# 3175 consolid
# 3176 playoff
# 3177 embark
# 3178 voyag
# 3179 mozzi
# 3180 weaker
# 3181 birth
# 3182 past
# 3183 verkerk
# 3184 brew
# 3185 contractor
# 3186 ribbon
# 3187 anzac
# 3188 unfair
# 3189 recreat
# 3190 ail
# 3191 competit
# 3192 ongo
# 3193 minimis
# 3194 shouldnt
# 3195 expel
# 3196 appropri
# 3197 meninde
# 3198 wicket
# 3199 knee
# 3200 loot
# 3201 amrozi
# 3202 archibald
# 3203 prize
# 3204 artist
# 3205 barrichello
# 3206 schu
# 3207 upstag
# 3208 berri
# 3209 broadband
# 3210 stunt
# 3211 bulldoz
# 3212 appli
# 3213 button
# 3214 fisichella
# 3215 cambodia
# 3216 financi
# 3217 coober
# 3218 opal
# 3219 pedi
# 3220 cool
# 3221 carniv
# 3222 pedestrian
# 3223 burk
# 3224 bear
# 3225 virtual
# 3226 offshor
# 3227 anchor
# 3228 slash
# 3229 beetl
# 3230 editor
# 3231 edward
# 3232 expo
# 3233 distress
# 3234 index
# 3235 fischer
# 3236 gang
# 3237 compli
# 3238 summon
# 3239 expans
# 3240 stall
# 3241 lurk
# 3242 fenc
# 3243 gap
# 3244 qatar
# 3245 prosecut
# 3246 gunnedah
# 3247 overboard
# 3248 curb
# 3249 hurrican
# 3250 swamp
# 3251 mistak
# 3252 energi
# 3253 gut
# 3254 unrest
# 3255 jockey
# 3256 opt
# 3257 hole
# 3258 larg
# 3259 sweet
# 3260 crippl
# 3261 mango
# 3262 lure
# 3263 tout
# 3264 muscat
# 3265 nervous
# 3266 cano
# 3267 palac
# 3268 theatr
# 3269 parkinson
# 3270 copper
# 3271 wire
# 3272 puppi
# 3273 cell
# 3274 stem
# 3275 raikkonen
# 3276 rig
# 3277 dive
# 3278 lobster
# 3279 skip
# 3280 well
# 3281 june
# 3282 collid
# 3283 residenti
# 3284 algerian
# 3285 technic
# 3286 tennant
# 3287 ballarat
# 3288 justifi
# 3289 file
# 3290 viduka
# 3291 popular
# 3292 spoon
# 3293 wooden
# 3294 wayn
# 3295 fergi
# 3296 wenger
# 3297 westpac
# 3298 mandela
# 3299 suit
# 3300 equal
# 3301 argentin
# 3302 winless
# 3303 intent
# 3304 bracken
# 3305 surfer
# 3306 orchestra
# 3307 chile
# 3308 cigarett
# 3309 compens
# 3310 massacr
# 3311 srebrenica
# 3312 amid
# 3313 advis
# 3314 extrem
# 3315 fundrais
# 3316 adopt
# 3317 hantuchova
# 3318 jordan
# 3319 margin
# 3320 imperson
# 3321 mason
# 3322 abort
# 3323 bold
# 3324 calm
# 3325 omalley
# 3326 bacon
# 3327 pampl
# 3328 breaker
# 3329 hockey
# 3330 tune
# 3331 borrow
# 3332 clinch
# 3333 tens
# 3334 fastest
# 3335 hostil
# 3336 defer
# 3337 tiwi
# 3338 skull
# 3339 zimbabwean
# 3340 hamper
# 3341 overpow
# 3342 defus
# 3343 armour
# 3344 jaguar
# 3345 proof
# 3346 skyrocket
# 3347 april
# 3348 distribut
# 3349 davenport
# 3350 chilean
# 3351 lade
# 3352 preseason
# 3353 tactic
# 3354 alight
# 3355 cook
# 3356 status
# 3357 henri
# 3358 separ
# 3359 peruvian
# 3360 warrant
# 3361 use
# 3362 carter
# 3363 villag
# 3364 bolton
# 3365 burglari
# 3366 lismor
# 3367 activist
# 3368 memorabilia
# 3369 montoya
# 3370 seizur
# 3371 munich
# 3372 articl
# 3373 hostag
# 3374 stanhop
# 3375 photo
# 3376 gunshot
# 3377 clue
# 3378 adam
# 3379 faith
# 3380 option
# 3381 holland
# 3382 style
# 3383 offens
# 3384 lie
# 3385 klitschko
# 3386 let
# 3387 innisfail
# 3388 neck
# 3389 rapid
# 3390 runner
# 3391 leap
# 3392 rifl
# 3393 bangladeshi
# 3394 tortur
# 3395 czech
# 3396 republ
# 3397 tropic
# 3398 observ
# 3399 shooter
# 3400 campbel
# 3401 stuff
# 3402 connolli
# 3403 outburst
# 3404 anderson
# 3405 stalem
# 3406 archaeologist
# 3407 religi
# 3408 excus
# 3409 trace
# 3410 barri
# 3411 sheen
# 3412 listen
# 3413 enjoy
# 3414 beatl
# 3415 behav
# 3416 bellami
# 3417 taliban
# 3418 size
# 3419 shell
# 3420 violat
# 3421 canoeist
# 3422 chicago
# 3423 guild
# 3424 screen
# 3425 classi
# 3426 ebola
# 3427 pip
# 3428 craig
# 3429 beer
# 3430 easter
# 3431 expuls
# 3432 emerton
# 3433 coin
# 3434 fingleton
# 3435 flinder
# 3436 dark
# 3437 furyk
# 3438 habitat
# 3439 tire
# 3440 trescothick
# 3441 cent
# 3442 certain
# 3443 odd
# 3444 knowl
# 3445 mar
# 3446 glide
# 3447 accommod
# 3448 contact
# 3449 maiden
# 3450 morrison
# 3451 motor
# 3452 washington
# 3453 thai
# 3454 mater
# 3455 reaffirm
# 3456 dubbo
# 3457 raaf
# 3458 breast
# 3459 lord
# 3460 primus
# 3461 foreshadow
# 3462 surrend
# 3463 feud
# 3464 endors
# 3465 shellharbour
# 3466 haze
# 3467 meander
# 3468 tumut
# 3469 warplan
# 3470 larkham
# 3471 disney
# 3472 happen
# 3473 sunday
# 3474 blewett
# 3475 disarma
# 3476 engulf
# 3477 biggest
# 3478 manufactur
# 3479 sweat
# 3480 carlton
# 3481 salari
# 3482 cherri
# 3483 undermin
# 3484 social
# 3485 podium
# 3486 embrac
# 3487 lincoln
# 3488 exceed
# 3489 remind
# 3490 plea
# 3491 exploit
# 3492 endang
# 3493 fleme
# 3494 balconi
# 3495 cessnock
# 3496 reveng
# 3497 courthous
# 3498 uncertain
# 3499 allergi
# 3500 surplus
# 3501 ranch
# 3502 megawati
# 3503 midfield
# 3504 inaugur
# 3505 keat
# 3506 relationship
# 3507 medallist
# 3508 lynch
# 3509 paedophilia
# 3510 girlfriend
# 3511 mauresmo
# 3512 mcguir
# 3513 lagoon
# 3514 smell
# 3515 tumour
# 3516 blunder
# 3517 constitut
# 3518 condol
# 3519 bat
# 3520 ratifi
# 3521 seismic
# 3522 otway
# 3523 peninsula
# 3524 greenhous
# 3525 underground
# 3526 ball
# 3527 mcmillan
# 3528 stori
# 3529 goat
# 3530 dampen
# 3531 romania
# 3532 showground
# 3533 skywest
# 3534 grafton
# 3535 sunderland
# 3536 beekeep
# 3537 honey
# 3538 strain
# 3539 psychologist
# 3540 satellit
# 3541 penni
# 3542 premium
# 3543 climat
# 3544 waff
# 3545 regular
# 3546 umpir
# 3547 afghanistan
# 3548 data
# 3549 entertain
# 3550 cuba
# 3551 aquif
# 3552 capabl
# 3553 grave
# 3554 christian
# 3555 cattlemen
# 3556 prone
# 3557 recommend
# 3558 complex
# 3559 categori
# 3560 stat
# 3561 twin
# 3562 fairfax
# 3563 diet
# 3564 moral
# 3565 ergon
# 3566 clemenc
# 3567 falun
# 3568 duke
# 3569 freez
# 3570 yachtsman
# 3571 sewerag
# 3572 subdivis
# 3573 mishap
# 3574 advisori
# 3575 frighten
# 3576 skydiv
# 3577 skipper
# 3578 landslid
# 3579 laverton
# 3580 societi
# 3581 oncolog
# 3582 diesel
# 3583 matilda
# 3584 waltz
# 3585 mcgradi
# 3586 capac
# 3587 difficult
# 3588 paradis
# 3589 abalon
# 3590 acquir
# 3591 roadsid
# 3592 clubhous
# 3593 dock
# 3594 reinforc
# 3595 ryan
# 3596 jacket
# 3597 sail
# 3598 tucker
# 3599 momentum
# 3600 model
# 3601 seminar
# 3602 serb
# 3603 brochur
# 3604 tafe
# 3605 soft
# 3606 fungus
# 3607 turner
# 3608 reced
# 3609 gregan
# 3610 wallabi
# 3611 shot
# 3612 rehabilit
# 3613 snag
# 3614 wetland
# 3615 eel
# 3616 breakaway
# 3617 woodbridg
# 3618 compound
# 3619 woomera
# 3620 languag
# 3621 exist
# 3622 stockpil
# 3623 amaz
# 3624 sixer
# 3625 defi
# 3626 retreat
# 3627 later
# 3628 arrang
# 3629 sweden
# 3630 pastor
# 3631 blatter
# 3632 dialysi
# 3633 incorrect
# 3634 jobless
# 3635 reconsid
# 3636 ridicul
# 3637 thredbo
# 3638 captainci
# 3639 carey
# 3640 collingwood
# 3641 cyclist
# 3642 maria
# 3643 replay
# 3644 moroccan
# 3645 matera
# 3646 unlock
# 3647 enron
# 3648 shelv
# 3649 desalin
# 3650 cave
# 3651 dismantl
# 3652 robinson
# 3653 indemn
# 3654 fade
# 3655 warfar
# 3656 reput
# 3657 snare
# 3658 locust
# 3659 toss
# 3660 lpga
# 3661 unfit
# 3662 toowoomba
# 3663 comm
# 3664 chart
# 3665 robot
# 3666 specialist
# 3667 appeas
# 3668 shore
# 3669 pine
# 3670 decreas
# 3671 seri
# 3672 penalis
# 3673 robertson
# 3674 progress
# 3675 slowli
# 3676 mcewen
# 3677 spike
# 3678 smart
# 3679 sorenstam
# 3680 stomach
# 3681 subject
# 3682 artifici
# 3683 panda
# 3684 serbia
# 3685 greatest
# 3686 cosgrov
# 3687 ullrich
# 3688 qlds
# 3689 khmer
# 3690 roug
# 3691 command
# 3692 pneumonia
# 3693 widow
# 3694 wildcat
# 3695 ward
# 3696 limelight
# 3697 upris
# 3698 aceh
# 3699 slug
# 3700 credibl
# 3701 threshold
# 3702 batchelor
# 3703 egg
# 3704 rebound
# 3705 bass
# 3706 strait
# 3707 bonus
# 3708 outbreak
# 3709 worsen
# 3710 cdep
# 3711 demis
# 3712 mandatori
# 3713 resurrect
# 3714 cop
# 3715 billionair
# 3716 copi
# 3717 correct
# 3718 darci
# 3719 spare
# 3720 rag
# 3721 mall
# 3722 dolphin
# 3723 dozen
# 3724 serbian
# 3725 section
# 3726 limeston
# 3727 grey
# 3728 harvey
# 3729 norman
# 3730 renal
# 3731 stricken
# 3732 hollywood
# 3733 homicid
# 3734 indon
# 3735 stroke
# 3736 khan
# 3737 caloundra
# 3738 asbesto
# 3739 medico
# 3740 district
# 3741 hamilton
# 3742 diabet
# 3743 patriot
# 3744 repriev
# 3745 hefti
# 3746 caledonia
# 3747 stag
# 3748 magazin
# 3749 extinguish
# 3750 portrait
# 3751 sheikh
# 3752 toler
# 3753 roff
# 3754 scale
# 3755 senden
# 3756 kurdish
# 3757 outsourc
# 3758 unusu
# 3759 outlaw
# 3760 partial
# 3761 sky
# 3762 scrutini
# 3763 amateur
# 3764 fairytal
# 3765 atapattu
# 3766 roadmap
# 3767 raider
# 3768 trash
# 3769 cipollini
# 3770 sprint
# 3771 overwhelm
# 3772 kasper
# 3773 underestim
# 3774 collect
# 3775 gatlin
# 3776 urban
# 3777 leaderboard
# 3778 stroll
# 3779 hunger
# 3780 dedic
# 3781 romp
# 3782 lehmann
# 3783 mortlock
# 3784 shoulder
# 3785 cling
# 3786 lifelin
# 3787 inact
# 3788 treasuri
# 3789 immedi
# 3790 implement
# 3791 palmerston
# 3792 glen
# 3793 vigil
# 3794 liner
# 3795 previous
# 3796 premiership
# 3797 bedroom
# 3798 fit
# 3799 dragon
# 3800 headlin
# 3801 starter
# 3802 mercuri
# 3803 caucus
# 3804 inner
# 3805 transpar
# 3806 dilemma
# 3807 symond
# 3808 transit
# 3809 shaki
# 3810 boy
# 3811 exit
# 3812 ethnic
# 3813 perfect
# 3814 hansen
# 3815 highland
# 3816 tragic
# 3817 foot
# 3818 formal
# 3819 aggress
# 3820 bronco
# 3821 leonard
# 3822 magpi
# 3823 jack
# 3824 setback
# 3825 evalu
# 3826 accredit
# 3827 mitchel
# 3828 elizabeth
# 3829 quarantin
# 3830 rover
# 3831 shiit
# 3832 leon
# 3833 sierra
# 3834 prevail
# 3835 spectat
# 3836 gasp
# 3837 upper
# 3838 escape
# 3839 recaptur
# 3840 tunisia
# 3841 arnhem
# 3842 intimid
# 3843 templ
# 3844 timelin
# 3845 throw
# 3846 eddi
# 3847 aplenti
# 3848 chest
# 3849 injunct
# 3850 myer
# 3851 refineri
# 3852 relianc
# 3853 cream
# 3854 seafood
# 3855 youngster
# 3856 refere
# 3857 footbal
# 3858 refer
# 3859 reckless
# 3860 dental
# 3861 sweeten
# 3862 icpa
# 3863 toast
# 3864 hurdl
# 3865 reason
# 3866 unclear
# 3867 machin
# 3868 rev
# 3869 martyn
# 3870 finger
# 3871 boot
# 3872 origin
# 3873 miseri
# 3874 shoalhaven
# 3875 pasminco
# 3876 peter
# 3877 papuan
# 3878 detect
# 3879 unruli
# 3880 mysteri
# 3881 backlash
# 3882 chain
# 3883 circuit
# 3884 hugh
# 3885 shepparton
# 3886 voluntari
# 3887 influenc
# 3888 quest
# 3889 punch
# 3890 talli
# 3891 mill
# 3892 biki
# 3893 buffer
# 3894 mandat
# 3895 exempt
# 3896 poki
# 3897 word
# 3898 metr
# 3899 ivanisev
# 3900 wimbledon
# 3901 nude
# 3902 fallout
# 3903 widen
# 3904 acoss
# 3905 morn
# 3906 bishop
# 3907 heal
# 3908 hatch
# 3909 viewer
# 3910 koala
# 3911 mop
# 3912 dfat
# 3913 syria
# 3914 vet
# 3915 cast
# 3916 leak
# 3917 matter
# 3918 genet
# 3919 tag
# 3920 flee
# 3921 luck
# 3922 discoveri
# 3923 gough
# 3924 yorkshir
# 3925 can
# 3926 silenc
# 3927 nino
# 3928 calf
# 3929 hawthorn
# 3930 abolit
# 3931 outcom
# 3932 straight
# 3933 tyre
# 3934 deem
# 3935 essenti
# 3936 marina
# 3937 birdsvill
# 3938 sober
# 3939 mori
# 3940 bore
# 3941 bout
# 3942 prim
# 3943 asid
# 3944 seoul
# 3945 son
# 3946 net
# 3947 temporarili
# 3948 lay
# 3949 racq
# 3950 standardis
# 3951 effici
# 3952 ultimatum
# 3953 symptom
# 3954 warlord
# 3955 smith
# 3956 walkout
# 3957 tampa
# 3958 peak
# 3959 indec
# 3960 whatmor
# 3961 loyalti
# 3962 thunderbird
# 3963 kidney
# 3964 graffiti
# 3965 creditor
# 3966 unsecur
# 3967 oxfam
# 3968 whitak
# 3969 malaysian
# 3970 mitsubishi
# 3971 weight
# 3972 abduct
# 3973 assum
# 3974 thumb
# 3975 spinal
# 3976 hypocrit
# 3977 gene
# 3978 identif
# 3979 diver
# 3980 applaud
# 3981 dissid
# 3982 traffick
# 3983 dust
# 3984 kurd
# 3985 crude
# 3986 mornington
# 3987 syrian
# 3988 sven
# 3989 gallop
# 3990 hypocrisi
# 3991 holm
# 3992 sway
# 3993 martha
# 3994 kennedi
# 3995 latif
# 3996 structur
# 3997 leicest
# 3998 luczak
# 3999 miami
# 4000 sword
# 4001 motel
# 4002 nairn
# 4003 carpet
# 4004 palm
# 4005 picnic
# 4006 withstand
# 4007 juventus
# 4008 boati
# 4009 santo
# 4010 voic
# 4011 network
# 4012 hackett
# 4013 rivalri
# 4014 commut
# 4015 tram
# 4016 mareeba
# 4017 airspac
# 4018 chequ
# 4019 forg
# 4020 propaganda
# 4021 sound
# 4022 dinner
# 4023 gag
# 4024 monaro
# 4025 turf
# 4026 cuban
# 4027 tool
# 4028 text
# 4029 mortgag
# 4030 queri
# 4031 solicitor
# 4032 asio
# 4033 duel
# 4034 harmoni
# 4035 reconcili
# 4036 unconcern
# 4037 jihad
# 4038 basra
# 4039 businessman
# 4040 poverti
# 4041 mammal
# 4042 gale
# 4043 didnt
# 4044 molik
# 4045 pratt
# 4046 download
# 4047 supplier
# 4048 demount
# 4049 substanc
# 4050 prestigi
# 4051 apprentic
# 4052 ryle
# 4053 patch
# 4054 souness
# 4055 digger
# 4056 passion
# 4057 cruelti
# 4058 lectur
# 4059 clarifi
# 4060 decapit
# 4061 extremist
# 4062 heighten
# 4063 alli
# 4064 mosul
# 4065 argentinian
# 4066 everton
# 4067 brave
# 4068 torch
# 4069 grip
# 4070 strateg
# 4071 demetriou
# 4072 elig
# 4073 interim
# 4074 felt
# 4075 coup
# 4076 quicker
# 4077 hazard
# 4078 hostel
# 4079 liquor
# 4080 ninth
# 4081 blackout
# 4082 unlaw
# 4083 uluru
# 4084 mcgauran
# 4085 phoenix
# 4086 pentagon
# 4087 reign
# 4088 entitl
# 4089 orchard
# 4090 queen
# 4091 humili
# 4092 devast
# 4093 sizzl
# 4094 seagul
# 4095 derwent
# 4096 sewag
# 4097 shevchenko
# 4098 onslaught
# 4099 republican
# 4100 racist
# 4101 vieira
# 4102 footag
# 4103 resort
# 4104 despair
# 4105 contamin
# 4106 ablaz
# 4107 annihil
# 4108 probabl
# 4109 demonstr
# 4110 dravid
# 4111 swing
# 4112 entir
# 4113 gunfir
# 4114 matthew
# ...
# 5428 forster
# 5429 jesus
# 5430 outcri
# 5431 warrnambool
# 5432 taint
# 5433 admin
# 5434 movi
# 5435 cityrail
# 5436 earmark
# 5437 hitler
# 5438 broker
# 5439 floodwat
# 5440 freedman
# 5441 smear
# 5442 giteau
# 5443 ref
# 5444 orthopaed
# 5445 narrabri
# 5446 parrot
# 5447 rocca
# 5448 romanian
# 5449 interpret
# 5450 slovak
# 5451 bok
# 5452 cutback
# 5453 rust
# 5454 trot
# 5624 volatil
# 5625 clement
# 5626 larsson
# 5627 luca
# 5628 unlicens
# 5629 dispos
# 5630 carnarvon
# 5631 lgaq
# 5632 ohern
# 5633 rewrit
# 5634 shipwreck
# 5635 out
# 5636 sparkl
# 5637 laidley
# 5638 pageant
# 5639 archiv
# 5640 shame
# 5641 sharp
# 5642 belarus
# 5643 decri
# 5644 comput
# 5645 bullimor
# 5646 compos
# 5647 montreal
# 5648 juic
# 5649 ladder
# 5650 plenti
# 5651 kyi
# 5652 stockholm
# 5653 oriol
# 5654 uniform
# 5655 herald
# 5656 beachgoer
# 5657 hardest
# 5658 soften
# 5659 carrol
# 5660 descend
# 5661 maori
# 5662 python
# 5663 quot
# 5664 logan
# 5665 lennon
# 5666 definit
# 5667 healthcar
# 5668 bathurst
# 5669 larri
# 5670 harmison
# 5671 lopez
# 5672 picasso
# 5673 piri
# 5674 snapshot
# 5675 ultra
# 5676 anthoni
# 5677 nonsens
# 5678 thorn
# 5679 dirt
# 5680 devonport
# 5681 forb
# 5682 permiss
# 5683 grill
# 5684 hamstr
# 5685 oval
# 5686 litter
# 5687 rotari
# 5688 secker
# 5689 communist
# 5690 diagnosi
# 5691 refug
# 5692 backer
# 5693 usag
# 5694 classroom
# 5695 heap
# 5696 consecut
# 5697 burnett
# 5698 rodeo
# 5699 resumpt
# 5700 quarri
# 5701 territorian
# 5702 wilson
# 5703 loser
# 5704 yachti
# 5705 yahoo
# 5706 barcaldin
# 5707 septic
# 5708 hepat
# 5709 scanner
# 5710 livingston
# 5711 murchison
# 5712 biker
# 5713 exhum
# 5714 liberian
# 5715 comet
# 5716 exagger
# 5717 bitter
# 5718 colli
# 5719 quell
# 5720 congest
# 5721 heathrow
# 5722 knockout
# 5723 generous
# 5724 wwii
# 5725 mosquito
# 5726 sluggish
# 5727 slim
# 5728 kosovo
# 5729 urin
# 5730 wada
# 5731 toni
# 5732 boral
# 5733 whistl
# 5734 contradict
# 5735 swallow
# 5736 cathedr
# 5737 alter
# 5738 endeavour
# 5739 pond
# 5740 evas
# 5741 flatley
# 5742 gorg
# 5743 leski
# 5744 wangaratta
# 5745 countdown
# 5746 fevola
# 5747 disadvantag
# 5748 menzi
# 5749 physic
# 5750 wyndham
# 5751 daniel
# 5752 reiter
# 5753 tuesday
# 5754 georgian
# 5755 headland
# 5756 sapphir
# 5757 hemp
# 5758 cargo
# 5759 boil
# 5760 laport
# 5761 monrovia
# 5762 macklin
# 5763 output
# 5764 scammer
# 5765 lazi
# 5766 woodford
# 5767 scream
# 5768 sharapova
# 5769 inn
# 5770 libya
# 5771 franklin
# 5772 counti
# 5773 safari
# 5774 toyota
# 5775 beck
# 5776 betray
# 5777 dictat
# 5778 chocol
# 5779 youni
# 5780 rumford
# 5781 broaden
# 5782 cameron
# 5783 hitman
# 5784 kiss
# 5785 empir
# 5786 millennium
# 5787 speedster
# 5788 feedback
# 5789 conspiraci
# 5790 sevilla
# 5791 swell
# 5792 coag
# 5793 alumina
# 5794 backlog
# 5795 warehous
# 5796 moor
# 5968 floor
# 5969 lawrenc
# 5970 needi
# 5971 grampian
# 5972 ningaloo
# 5973 freddi
# 5974 polo
# 5975 gibb
# 5976 naidoc
# 5977 adler
# 5978 keke
# 5979 chainsaw
# 5980 boe
# 5981 baker
# 5982 bubbl
# 5983 waterfront
# 5984 baggaley
# 5985 moreton
# 5986 simon
# 5987 wan
# 5988 humpback
# 5989 tangl
# 5990 ranieri
# 5991 inappropri
# 5992 lanc
# 5993 neill
# 5994 antiqu
# 5995 modern
# 5996 gaudio
# 5997 pluto
# 5998 methadon
# 5999 wodonga
# 6000 duf
# 6001 polynesia
# 6002 extraordinari
# 6003 queue
# 6004 sperm
# 6005 stud
# 6006 slur
# 6007 stormi
# 6008 volleybal
# 6009 niger
# 6010 vendor
# 6011 reagan
# 6012 rotavirus
# 6013 mandurah
# 6014 stargaz
# 6015 bollywood
# 6016 kakadu
# 6017 translat
# 6018 cloth
# 6019 matur
# 6020 luna
# 6021 ethiopian
# 6022 manila
# 6023 shelf
# 6024 gypsi
# 6025 scrutinis
# 6026 gymnast
# 6027 vicious
# 6028 discount
# 6029 unpaid
# 6030 consumpt
# 6031 musician
# 6032 lachlan
# 6033 leg
# 6034 robinval
# 6035 pave
# 6036 cunningham
# 6037 sterilis
# 6038 myth
# 6039 bleak
# 6040 nationwid
# 6041 notif
# 6042 wolfowitz
# 6043 sadden
# 6044 courier
# 6045 akermani
# 6046 lappin
# 6047 accord
# 6048 taunt
# 6049 gardin
# 6050 worsfold
# 6051 ingal
# 6052 rep
# 6053 curti
# 6054 swelter
# 6055 historian
# 6056 gatton
# 6057 nile
# 6058 norfolk
# 6059 fern
# 6060 authoris
# 6061 hotter
# 6062 feedlot
# 6063 glass
# 6064 rafah
# 6065 lender
# 6066 belconnen
# 6067 judd
# 6068 santa
# 6069 honiara
# 6070 piec
# 6071 minichiello
# 6072 nebo
# 6073 playground
# 6074 predat
# 6075 bjorn
# 6076 nomine
# 6077 muster
# 6078 brough
# 6079 temp
# 6080 dummi
# 6081 bledislo
# 6082 root
# 6083 crocker
# 6084 cement
# 6085 bondi
# 6086 infight
# 6087 studio
# 6088 leukaemia
# 6089 loeb
# 6090 shane
# 6091 nixon
# 6092 redknapp
# 6093 lampard
# 6094 unsettl
# 6095 innov
# 6096 badminton
# 6097 echuca
# 6098 intrud
# 6099 tottenham
# 6100 hasten
# 6101 gibbon
# 6102 scope
# 6103 soni
# 6104 epic
# 6105 flyer
# 6106 vatican
# 6107 roch
# 6108 spenc
# 6109 pinochet
# 6110 truffl
# 6111 vandalis
# 6112 sunni
# 6113 ear
# 6114 headquart
# 6115 bolivian
# 6116 acquitt
# 6117 nest
# 6118 inzamam
# 6119 fein
# 6120 sinn
# 6121 gas
# 6122 oblig
# 6123 marriott
# 6124 currenc
# 6125 carp
# 6126 rave
# 6127 manilla
# 6128 vindic
# 6129 kuznetsova
# 6130 naracoort
# 6131 granni
# 6132 huon
# 6133 rediscov
# 6134 arctic
# 6135 sham
# 6136 joh
# 6137 succeed
# 6138 ettridg
# 6310 gower
# 6311 lane
# 6312 kremlin
# 6313 roebourn
# 6314 dallaglio
# 6315 switkowski
# 6316 grandmoth
# 6317 measl
# 6318 coco
# 6319 offload
# 6320 limp
# 6321 horn
# 6322 grinham
# 6323 southport
# 6324 cloncurri
# 6325 patholog
# 6326 somalia
# 6327 johnston
# 6328 hopman
# 6329 allegi
# 6330 belong
# 6331 rack
# 6332 strangl
# 6333 emerald
# 6334 caulfield
# 6335 sikh
# 6336 wadey
# 6337 astl
# 6338 umaga
# 6339 boswel
# 6340 pornographi
# 6341 courag
# 6342 tare
# 6343 rollout
# 6344 deviat
# 6345 inventor
# 6346 more
# 6347 coffer
# 6348 gay
# 6349 exam
# 6350 mercenari
# 6351 laxman
# 6352 vincent
# 6353 racecours
# 6354 kooyong
# 6355 moodi
# 6356 waca
# 6357 lesli
# 6358 bowel
# 6359 bauxit
# 6360 dampier
# 6361 greyhound
# 6362 complic
# 6363 stalker
# 6364 googl
# 6365 flemington
# 6366 credenti
# 6367 kickback
# 6368 chad
# 6369 raze
# 6370 katich
# 6371 inverel
# 6372 fool
# 6373 dugong
# 6374 retrench
# 6375 culprit
# 6376 halliburton
# 6377 brigalow
# 6378 leaver
# 6379 petrova
# 6380 auspin
# 6381 balibo
# 6382 currumbin
# 6383 flanneri
# 6384 morwel
# 6385 elvstroem
# 6386 yuko
# 6387 paralympian
# 6388 simplot
# 6389 diva
# 6390 makyb
# 6391 shorten
# 6392 iceberg
# 6393 embargo
# 6394 midland
# 6395 oversuppli
# 6396 idol
# 6397 statehood
# 6398 grove
# 6399 titan
# 6400 wilko
# 6401 cartoon
# 6402 chess
# 6403 kearn
# 6404 sophi
# 6405 impeach
# 6406 rioter
# 6407 plotter
# 6408 detector
# 6409 carney
# 6410 spencer
# 6411 gascoyn
# 6412 courtney
# 6413 synagogu
# 6414 luggag
# 6415 takeaway
# 6416 passag
# 6417 weightlift
# 6418 pardon
# 6419 launcher
# 6420 rottnest
# 6421 brock
# 6422 figo
# 6423 saha
# 6424 cronulla
# 6425 ripper
# 6426 vline
# 6427 vizard
# 6428 valid
# 6429 gillard
# 6430 gilli
# 6431 raper
# 6432 jetstar
# 6433 deporte
# 6434 landscap
# 6435 greenough
# 6436 gore
# 6437 diari
# 6438 coastguard
# 6439 parmalat
# 6440 fortescu
# 6441 chimp
# 6442 skandia
# 6443 belmont
# 6444 hiroshima
# 6445 schwarzer
# 6446 kitten
# 6447 seymour
# 6448 angola
# 6449 beller
# 6450 paralymp
# 6451 headscarf
# 6452 probat
# 6453 moomba
# 6454 martian
# 6455 scrub
# 6456 dakar
# 6457 margaret
# 6458 kumbl
# 6459 haiti
# 6460 patel
# 6461 britney
# 6462 fenech
# 6463 paraglid
# 6464 niue
# 6465 doha
# 6466 chennai
# 6467 causeway
# 6468 tait
# 6469 revok
# 6470 guccion
# 6471 walgett
# 6472 amazon
# 6473 railcorp
# 6474 foxtel
# 6475 glider
# 6476 hensbi
# 6477 bellingen
# 6478 bono
# 6479 shoalwat
# 6480 walter
# 6481 shortcom
# 6649 ramsi
# 6650 pietersen
# 6651 baton
# 6652 hariri
# 6653 ingrid
# 6654 lightfoot
# 6655 seeney
# 6656 schiavo
# 6657 garuda
# 6658 qasim
# 6659 marburg
# 6660 flegg
# 6661 nia
# 6662 promontori
# 6663 korp
# 6664 podcast
# 6665 sniffabl
# 6666 ricki
# 6667 lockhart
# 6668 koran
# 6669 solon
# 6670 hilali
# 6671 georgiou
# 6672 ashbourn
# 6673 trujillo
# 6674 maxwel
# 6675 glenn
# 6676 arnold
# 6677 hiddink
# 6678 gillett
# 6679 mulrunji
# 6680 katrina
# 6681 ymca
# 6682 evacue
# 6683 gerard
# 6684 wilma
# 6685 nguyen
# 6686 workchoic
# 6687 jovic
# 6688 olmert
# 6689 asif
# 6690 desal
# 6691 westpoint
# 6692 gaven
# 6693 mutitjulu
# 6694 baillieu
# 6695 brethren
# 6696 brimbl
# 6697 glenda
# 6698 abcnew
# 6699 monica
# 6700 merapi
# 6701 kovco
# 6702 delezio
# 6703 alkatiri
# 6704 mogadishu
# 6705 panesar
# 6706 fretilin
# 6707 reinado
# 6708 mutijulu
# 6709 nodisplay
# 6710 traveston
# 6711 moti
# 6712 bainimarama
# 6713 orkopoulo
# 6714 obama
# 6715 tristar
# 6716 mckew
# 6717 broughton

# %%
# dictionary.cfs is a dict of (int, int) -> (token id, # occurences)

# this code shows (token id, word, # occurences)

count = 0
for k, v in dictionary.iteritems():
    print(k,v,dictionary.cfs[k])
    count += 1
    if count > 10:
        break
# Out:
# 0 broadcast 112
# 1 communiti 1668
# 2 decid 485
# 3 licenc 371
# 4 awar 162
# 5 defam 92
# 6 wit 531
# 7 call 2769
# 8 infrastructur 273
# 9 protect 882
# 10 summit 413

# %% [markdown]
# ** Gensim filter_extremes **
#
# [`filter_extremes(no_below=5, no_above=0.5, keep_n=100000)`](https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.filter_extremes)
#
# Filter out tokens that appear in
#
# * less than no_below documents (absolute number) or
# * more than no_above documents (fraction of total corpus size, not absolute number).
# * after (1) and (2), keep only the first keep_n most frequent tokens (or keep all if None).

# %%
'''
OPTIONAL STEP
Remove very rare and very common words:

- words appearing less than 15 times
- words appearing in more than 10% of all documents
'''
# TODO: apply dictionary.filter_extremes() with the parameters mentioned above
# https://stackoverflow.com/questions/66621708/filter-extreme-in-gensim
dictionary_filtered = dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n=100000)

# Filter out tokens that appear in

#    less than no_below documents (absolute number) or
#    more than no_above documents (fraction of total corpus size, not absolute number).
#    after (1) and (2), keep only the first keep_n most frequent tokens (or keep all if None).

# %% [markdown]
# ** Gensim doc2bow **
#
# [`doc2bow(document)`](https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2bow)
#
# * Convert document (a list of words) into the bag-of-words format = list of (token_id, token_count) 2-tuples. Each word is assumed to be a tokenized and normalized string (either unicode or utf8-encoded). No further preprocessing is done on the words in document; apply tokenization, stemming etc. before calling this method.

# %%
'''
Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
words and how many times those words appear. Save this to 'bow_corpus'
'''
# TODO
# https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2bow
# doc2bow(document, allow_update=False, return_missing=False)
# iterate over processed_docs. use list comphrehesion
bow_corpus = [dictionary.doc2bow(processed_doc ,allow_update=False, return_missing=False) for \
              processed_doc in processed_docs]

# %%
'''
Checking Bag of Words corpus for our sample document --> (token_id, token_count)
'''
print(document_num)
bow_corpus[document_num]
# Out:
# 4310
# [(71, 1), (107, 1), (462, 1), (3530, 1)]

# %%
'''
Preview BOW for our sample preprocessed document
'''
# Here document_num is document number 4310 which we have checked in Step 2
bow_doc_4310 = bow_corpus[document_num]

for i in range(len(bow_doc[0])):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_4310[i][0], 
                                                     dictionary[bow_doc_4310[i][0]], 
                                                     bow_doc_4310[i][1]))
# Out:
# Word 71 ("bushfir") appears 1 time.
# Word 107 ("help") appears 1 time.
# Word 462 ("rain") appears 1 time.
# Word 3530 ("dampen") appears 1 time.

# %% [markdown]
# ## Step 3.2: TF-IDF on our document set ##
#
# While performing TF-IDF on the corpus is not necessary for LDA implemention using the gensim model, it is recemmended. TF-IDF expects a bag-of-words (integer values) training corpus during initialization. During transformation, it will take a vector and return another vector of the same dimensionality.
#
# *Please note: The author of Gensim dictates the standard procedure for LDA to be using the Bag of Words model.*

# %% [markdown]
# ** TF-IDF stands for "Term Frequency, Inverse Document Frequency".**
#
# * It is a way to score the importance of words (or "terms") in a document based on how frequently they appear across multiple documents.
# * If a word appears frequently in a document, it's important. Give the word a high score. But if a word appears in many documents, it's not a unique identifier. Give the word a low score.
# * Therefore, common words like "the" and "for", which appear in many documents, will be scaled down. Words that appear frequently in a single document will be scaled up.
#
# In other words:
#
# * TF(w) = `(Number of times term w appears in a document) / (Total number of terms in the document)`.
# * IDF(w) = `log_e(Total number of documents / Number of documents with term w in it)`.
#
# ** For example **
#
# * Consider a document containing `100` words wherein the word 'tiger' appears 3 times.
# * The term frequency (i.e., tf) for 'tiger' is then:
#     - `TF = (3 / 100) = 0.03`.
#
# * Now, assume we have `10 million` documents and the word 'tiger' appears in `1000` of these. Then, the inverse document frequency (i.e., idf) is calculated as:
#     - `IDF = log(10,000,000 / 1,000) = 4`.
#
# * Thus, the Tf-idf weight is the product of these quantities:
#     - `TF-IDF = 0.03 * 4 = 0.12`.

# %%
'''
Create tf-idf model object using models.TfidfModel on 'bow_corpus' and save it to 'tfidf'
'''
from gensim import corpora, models

# TODO
# https://radimrehurek.com/gensim/models/tfidfmodel.html
# model = TfidfModel(corpus)  # fit model
tfidf = models.TfidfModel(bow_corpus)

# %%
'''
Apply transformation to the entire corpus and call it 'corpus_tfidf'
'''
# TODO
# https://radimrehurek.com/gensim/models/tfidfmodel.html
# vector = model[corpus[0]]  # apply model to the first corpus document
# this is wierd syntax
# Calling model[corpus] only creates a wrapper around the old corpus document stream – 
#  actual conversions are done on-the-fly, during document iteration. We cannot convert 
#  the entire corpus at the time of calling corpus_transformed = model[corpus], 
#  because that would mean storing the result in main memory, and that contradicts 
#  gensim’s objective of memory-indepedence.

corpus_tfidf = tfidf[bow_corpus] #apply model to entire corpus

# %%
'''
Preview TF-IDF scores for our first document --> --> (token_id, tfidf score)
'''
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.5959813347777092),
#  (1, 0.39204529549491984),
#  (2, 0.48531419274988147),
#  (3, 0.5055461098578569)]

# %%
# Here document_num is document number 4310 which we have checked in Step 2
bow_doc_0 = bow_corpus[0]

for i in range(len(bow_doc_0)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_0[i][0], 
                                                     dictionary[bow_doc_0[i][0]], 
                                                     bow_doc_0[i][1]))
# Out:
# Word 0 ("broadcast") appears 1 time.
# Word 1 ("communiti") appears 1 time.
# Word 2 ("decid") appears 1 time.
# Word 3 ("licenc") appears 1 time.

# %%
bow_corpus[0]
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 1)]

# %% [markdown]
# ## Step 4.1: Running LDA using Bag of Words ##
#
# We are going for 10 topics in the document corpus.
#
# ** We will be running LDA using all CPU cores to parallelize and speed up model training.**
#
# Some of the parameters we will be tweaking are:
#
# * **num_topics** is the number of requested latent topics to be extracted from the training corpus.
# * **id2word** is a mapping from word ids (integers) to words (strings). It is used to determine the vocabulary size, as well as for debugging and topic printing.
# * **workers** is the number of extra processes to use for parallelization. Uses all available cores by default.
# * **alpha** and **eta** are hyperparameters that affect sparsity of the document-topic (theta) and topic-word (lambda) distributions. We will let these be the default values for now(default value is `1/num_topics`)
#     - Alpha is the per document topic distribution.
#         * High alpha: Every document has a mixture of all topics(documents appear similar to each other).
#         * Low alpha: Every document has a mixture of very few topics
#
#     - Eta is the per topic word distribution.
#         * High eta: Each topic has a mixture of most words(topics appear similar to each other).
#         * Low eta: Each topic has a mixture of few words.
#
# * ** passes ** is the number of training passes through the corpus. For  example, if the training corpus has 50,000 documents, chunksize is  10,000, passes is 2, then online training is done in 10 updates:
#     * `#1 documents 0-9,999 `
#     * `#2 documents 10,000-19,999 `
#     * `#3 documents 20,000-29,999 `
#     * `#4 documents 30,000-39,999 `
#     * `#5 documents 40,000-49,999 `
#     * `#6 documents 0-9,999 `
#     * `#7 documents 10,000-19,999 `
#     * `#8 documents 20,000-29,999 `
#     * `#9 documents 30,000-39,999 `
#     * `#10 documents 40,000-49,999`

# %%
# LDA mono-core -- fallback code in case LdaMulticore throws an error on your machine
# lda_model = gensim.models.LdaModel(bow_corpus, 
#                                    num_topics = 10, 
#                                    id2word = dictionary,                                    
#                                    passes = 50)

# LDA multicore 
'''
Train your lda model using gensim.models.LdaMulticore and save it to 'lda_model'
'''
# TODO
# lda = LdaMulticore(common_corpus, id2word=common_dictionary, num_topics=10)
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics = 10, id2word = dictionary, passes = 15, workers = 3)

# %%
'''
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(topic, idx ))
    print("\n")
# Out:
# Topic: 0.026*"open" + 0.022*"test" + 0.019*"world" + 0.016*"take" + 0.015*"lead" + 0.014*"south" + 0.013*"aussi" + 0.013*"strike" + 0.012*"target" + 0.012*"action"
# Words: 0
#
#
# Topic: 0.037*"report" + 0.020*"resid" + 0.019*"deal" + 0.017*"inquiri" + 0.014*"releas" + 0.013*"trade" + 0.012*"blaze" + 0.012*"firefight" + 0.011*"bushfir" + 0.011*"compani"
# Words: 1
#
#
# Topic: 0.039*"kill" + 0.033*"crash" + 0.019*"attack" + 0.016*"closer" + 0.016*"die" + 0.015*"coast" + 0.015*"bomb" + 0.015*"continu" + 0.013*"road" + 0.013*"dead"
# Words: 2
#
#
# Topic: 0.040*"govt" + 0.039*"plan" + 0.032*"council" + 0.023*"urg" + 0.021*"fund" + 0.020*"water" + 0.015*"group" + 0.012*"chang" + 0.012*"servic" + 0.012*"seek"
# Words: 3
#
#
# Topic: 0.026*"say" + 0.018*"labor" + 0.017*"support" + 0.017*"elect" + 0.017*"defend" + 0.016*"govt" + 0.015*"protest" + 0.014*"minist" + 0.013*"chief" + 0.011*"howard"
# Words: 4
#
#
# Topic: 0.045*"warn" + 0.016*"nuclear" + 0.015*"safeti" + 0.014*"threat" + 0.013*"health" + 0.013*"win" + 0.012*"award" + 0.011*"liber" + 0.011*"save" + 0.010*"iran"
# Words: 5
#
#
# Topic: 0.018*"rise" + 0.017*"farmer" + 0.017*"price" + 0.015*"drought" + 0.014*"high" + 0.013*"market" + 0.013*"look" + 0.012*"rain" + 0.011*"feder" + 0.011*"studi"
# Words: 6
#
#
# Topic: 0.019*"iraq" + 0.018*"talk" + 0.015*"australia" + 0.014*"play" + 0.013*"hold" + 0.013*"lose" + 0.010*"clash" + 0.009*"troop" + 0.009*"victori" + 0.009*"injuri"
# Words: 7
#
#
# Topic: 0.073*"polic" + 0.031*"charg" + 0.027*"court" + 0.027*"face" + 0.019*"miss" + 0.019*"investig" + 0.019*"death" + 0.017*"jail" + 0.016*"drug" + 0.016*"murder"
# Words: 8
#
#
# Topic: 0.041*"claim" + 0.023*"deni" + 0.020*"break" + 0.014*"rescu" + 0.013*"home" + 0.012*"make" + 0.010*"condit" + 0.010*"nurs" + 0.010*"export" + 0.010*"hill"
# Words: 9

# %% [markdown]
# ### Classification of the topics ###
#
# Using the words in each topic and their corresponding weights, what categories were you able to infer?
#
# * 0: maybe nuclear?
# * 1: some kind of report
# * 2: war
# * 3: government
# * 4: politics / government
# * 5: nuclear stuff
# * 6: farm
# * 7: Iraq war involving Australia
# * 8: Crime
# * 9:

# %% [markdown]
# ## Step 4.2 Running LDA using TF-IDF ##

# %%
'''
Define lda model using corpus_tfidf, again using gensim.models.LdaMulticore()
'''
# TODO
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics = 10, id2word = dictionary, passes = 15, workers = 3)

# %%
'''
For each topic, we will explore the words occuring in that topic and its relative weight
'''
for idx, topic in lda_model_tfidf.print_topics(-1):
    print("Topic: {} Word: {}".format(idx, topic))
    print("\n")
# Out:
# Topic: 0 Word: 0.009*"teacher" + 0.009*"strike" + 0.009*"control" + 0.007*"mine" + 0.007*"right" + 0.007*"extend" + 0.007*"action" + 0.007*"legal" + 0.006*"govt" + 0.006*"worker"
#
#
# Topic: 1 Word: 0.014*"price" + 0.013*"market" + 0.012*"rise" + 0.008*"tiger" + 0.008*"toll" + 0.007*"profit" + 0.007*"retir" + 0.007*"blue" + 0.007*"share" + 0.007*"record"
#
#
# Topic: 2 Word: 0.007*"export" + 0.007*"govt" + 0.007*"respons" + 0.006*"wait" + 0.005*"growth" + 0.005*"live" + 0.005*"recycl" + 0.005*"list" + 0.005*"safe" + 0.005*"wheat"
#
#
# Topic: 3 Word: 0.008*"murray" + 0.007*"climat" + 0.007*"lebanon" + 0.007*"escap" + 0.007*"open" + 0.006*"alic" + 0.006*"emerg" + 0.006*"kangaroo" + 0.006*"festiv" + 0.005*"crop"
#
#
# Topic: 4 Word: 0.013*"council" + 0.013*"plan" + 0.013*"govt" + 0.012*"fund" + 0.010*"health" + 0.009*"urg" + 0.008*"water" + 0.007*"group" + 0.007*"boost" + 0.007*"concern"
#
#
# Topic: 5 Word: 0.025*"closer" + 0.019*"crash" + 0.011*"search" + 0.010*"miss" + 0.009*"die" + 0.009*"polic" + 0.009*"blaze" + 0.009*"coast" + 0.009*"rain" + 0.008*"fatal"
#
#
# Topic: 6 Word: 0.027*"charg" + 0.022*"polic" + 0.019*"court" + 0.016*"murder" + 0.015*"jail" + 0.013*"face" + 0.012*"investig" + 0.012*"death" + 0.011*"assault" + 0.010*"drug"
#
#
# Topic: 7 Word: 0.024*"kill" + 0.015*"iraq" + 0.011*"troop" + 0.010*"bomb" + 0.010*"injur" + 0.009*"attack" + 0.009*"blast" + 0.008*"nuclear" + 0.008*"iraqi" + 0.008*"iran"
#
#
# Topic: 8 Word: 0.011*"hick" + 0.009*"plead" + 0.008*"illeg" + 0.007*"rescu" + 0.007*"news" + 0.007*"fish" + 0.006*"guilti" + 0.006*"coal" + 0.006*"fiji" + 0.006*"rate"
#
#
# Topic: 9 Word: 0.012*"elect" + 0.011*"labor" + 0.011*"howard" + 0.009*"timor" + 0.009*"liber" + 0.008*"rudd" + 0.007*"govt" + 0.007*"poll" + 0.007*"senat" + 0.006*"anti"

# %% [markdown]
# ### Classification of the topics ###
#
# As we can see, when using tf-idf, heavier weights are given to words that are not as frequent which results in nouns being factored in. That makes it harder to figure out the categories as nouns can be hard to categorize. This goes to show that the models we apply depend on the type of corpus of text we are dealing with.
#
# Using the words in each topic and their corresponding weights, what categories could you find?
#
# * 0: teacher strike
# * 1: economics
# * 2: exports
# * 3: climate
# * 4: government council meeting regarding health funding
# * 5: maybe a car crash
# * 6: some kind of crime and journey through the justice system
# * 7: war or terrorism involving iran and maybe iraq
# * 8: some kind of crime, perhaps involving water
# * 9: government; maybe labor party election

# %% [markdown]
# ## Step 5.1: Performance evaluation by classifying sample document using LDA Bag of Words model##
#
# We will check to see where our test document would be classified.

# %%
'''
Text of sample document 4310
'''
processed_docs[4310]
# Out:
# ['rain', 'help', 'dampen', 'bushfir']

# %%
'''
Check which topic our test document belongs to using the LDA Bag of Words model.
'''
document_num = 4310
# Our test document is document number 4310

# TODO
# Our test document is document number 4310
for index, score in sorted(lda_model[bow_corpus[document_num]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.6043445467948914
# Topic: 0.018*"rise" + 0.017*"farmer" + 0.017*"price" + 0.015*"drought" + 0.014*"high" + 0.013*"market" + 0.013*"look" + 0.012*"rain" + 0.011*"feder" + 0.011*"studi"
#
# Score: 0.2356332540512085
# Topic: 0.037*"report" + 0.020*"resid" + 0.019*"deal" + 0.017*"inquiri" + 0.014*"releas" + 0.013*"trade" + 0.012*"blaze" + 0.012*"firefight" + 0.011*"bushfir" + 0.011*"compani"
#
# Score: 0.020003611221909523
# Topic: 0.040*"govt" + 0.039*"plan" + 0.032*"council" + 0.023*"urg" + 0.021*"fund" + 0.020*"water" + 0.015*"group" + 0.012*"chang" + 0.012*"servic" + 0.012*"seek"
#
# Score: 0.020003236830234528
# Topic: 0.073*"polic" + 0.031*"charg" + 0.027*"court" + 0.027*"face" + 0.019*"miss" + 0.019*"investig" + 0.019*"death" + 0.017*"jail" + 0.016*"drug" + 0.016*"murder"
#
# Score: 0.02000255510210991
# Topic: 0.026*"open" + 0.022*"test" + 0.019*"world" + 0.016*"take" + 0.015*"lead" + 0.014*"south" + 0.013*"aussi" + 0.013*"strike" + 0.012*"target" + 0.012*"action"
#
# Score: 0.02000255510210991
# Topic: 0.039*"kill" + 0.033*"crash" + 0.019*"attack" + 0.016*"closer" + 0.016*"die" + 0.015*"coast" + 0.015*"bomb" + 0.015*"continu" + 0.013*"road" + 0.013*"dead"
#
# Score: 0.02000255510210991
# Topic: 0.026*"say" + 0.018*"labor" + 0.017*"support" + 0.017*"elect" + 0.017*"defend" + 0.016*"govt" + 0.015*"protest" + 0.014*"minist" + 0.013*"chief" + 0.011*"howard"
#
# Score: 0.02000255510210991
# Topic: 0.045*"warn" + 0.016*"nuclear" + 0.015*"safeti" + 0.014*"threat" + 0.013*"health" + 0.013*"win" + 0.012*"award" + 0.011*"liber" + 0.011*"save" + 0.010*"iran"
#
# Score: 0.02000255510210991
# Topic: 0.019*"iraq" + 0.018*"talk" + 0.015*"australia" + 0.014*"play" + 0.013*"hold" + 0.013*"lose" + 0.010*"clash" + 0.009*"troop" + 0.009*"victori" + 0.009*"injuri"
#
# Score: 0.02000255510210991
# Topic: 0.041*"claim" + 0.023*"deni" + 0.020*"break" + 0.014*"rescu" + 0.013*"home" + 0.012*"make" + 0.010*"condit" + 0.010*"nurs" + 0.010*"export" + 0.010*"hill"

# %% [markdown]
# ### It has the highest probability (`0.6`) to be  part of the topic that we assigned as 6 (issues with climate and farms), which is the accurate classification. ###

# %% [markdown]
# ## Step 5.2: Performance evaluation by classifying sample document using LDA TF-IDF model##

# %%
'''
Check which topic our test document belongs to using the LDA TF-IDF model.
'''
# Our test document is document number 4310
for index, score in sorted(lda_model_tfidf[bow_corpus[document_num]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.8199763298034668
# Topic: 0.025*"closer" + 0.019*"crash" + 0.011*"search" + 0.010*"miss" + 0.009*"die" + 0.009*"polic" + 0.009*"blaze" + 0.009*"coast" + 0.009*"rain" + 0.008*"fatal"
#
# Score: 0.02000398375093937
# Topic: 0.013*"council" + 0.013*"plan" + 0.013*"govt" + 0.012*"fund" + 0.010*"health" + 0.009*"urg" + 0.008*"water" + 0.007*"group" + 0.007*"boost" + 0.007*"concern"
#
# Score: 0.020002974197268486
# Topic: 0.011*"hick" + 0.009*"plead" + 0.008*"illeg" + 0.007*"rescu" + 0.007*"news" + 0.007*"fish" + 0.006*"guilti" + 0.006*"coal" + 0.006*"fiji" + 0.006*"rate"
#
# Score: 0.020002782344818115
# Topic: 0.009*"teacher" + 0.009*"strike" + 0.009*"control" + 0.007*"mine" + 0.007*"right" + 0.007*"extend" + 0.007*"action" + 0.007*"legal" + 0.006*"govt" + 0.006*"worker"
#
# Score: 0.020002612844109535
# Topic: 0.008*"murray" + 0.007*"climat" + 0.007*"lebanon" + 0.007*"escap" + 0.007*"open" + 0.006*"alic" + 0.006*"emerg" + 0.006*"kangaroo" + 0.006*"festiv" + 0.005*"crop"
#
# Score: 0.020002488046884537
# Topic: 0.027*"charg" + 0.022*"polic" + 0.019*"court" + 0.016*"murder" + 0.015*"jail" + 0.013*"face" + 0.012*"investig" + 0.012*"death" + 0.011*"assault" + 0.010*"drug"
#
# Score: 0.020002448931336403
# Topic: 0.007*"export" + 0.007*"govt" + 0.007*"respons" + 0.006*"wait" + 0.005*"growth" + 0.005*"live" + 0.005*"recycl" + 0.005*"list" + 0.005*"safe" + 0.005*"wheat"
#
# Score: 0.020002208650112152
# Topic: 0.012*"elect" + 0.011*"labor" + 0.011*"howard" + 0.009*"timor" + 0.009*"liber" + 0.008*"rudd" + 0.007*"govt" + 0.007*"poll" + 0.007*"senat" + 0.006*"anti"
#
# Score: 0.02000219188630581
# Topic: 0.014*"price" + 0.013*"market" + 0.012*"rise" + 0.008*"tiger" + 0.008*"toll" + 0.007*"profit" + 0.007*"retir" + 0.007*"blue" + 0.007*"share" + 0.007*"record"
#
# Score: 0.020001951605081558
# Topic: 0.024*"kill" + 0.015*"iraq" + 0.011*"troop" + 0.010*"bomb" + 0.010*"injur" + 0.009*"attack" + 0.009*"blast" + 0.008*"nuclear" + 0.008*"iraqi" + 0.008*"iran"

# %% [markdown]
# ### It has the highest probability (`82%`) to be  part of the topic that we assigned as 5 which seems to involve a car crash. ###

# %% [markdown]
# ## Step 6: Testing model on unseen document ##

# %%
unseen_document = "My favorite sports activities are running and swimming."

# Data preprocessing step for the unseen document
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.4199610948562622	 Topic: 0.026*"open" + 0.022*"test" + 0.019*"world" + 0.016*"take" + 0.015*"lead"
# Score: 0.22001239657402039	 Topic: 0.045*"warn" + 0.016*"nuclear" + 0.015*"safeti" + 0.014*"threat" + 0.013*"health"
# Score: 0.21997405588626862	 Topic: 0.019*"iraq" + 0.018*"talk" + 0.015*"australia" + 0.014*"play" + 0.013*"hold"
# Score: 0.020011387765407562	 Topic: 0.039*"kill" + 0.033*"crash" + 0.019*"attack" + 0.016*"closer" + 0.016*"die"
# Score: 0.02001088298857212	 Topic: 0.026*"say" + 0.018*"labor" + 0.017*"support" + 0.017*"elect" + 0.017*"defend"
# Score: 0.02000684104859829	 Topic: 0.040*"govt" + 0.039*"plan" + 0.032*"council" + 0.023*"urg" + 0.021*"fund"
# Score: 0.020006731152534485	 Topic: 0.037*"report" + 0.020*"resid" + 0.019*"deal" + 0.017*"inquiri" + 0.014*"releas"
# Score: 0.02000553533434868	 Topic: 0.018*"rise" + 0.017*"farmer" + 0.017*"price" + 0.015*"drought" + 0.014*"high"
# Score: 0.02000553533434868	 Topic: 0.073*"polic" + 0.031*"charg" + 0.027*"court" + 0.027*"face" + 0.019*"miss"
# Score: 0.02000553533434868	 Topic: 0.041*"claim" + 0.023*"deni" + 0.020*"break" + 0.014*"rescu" + 0.013*"home"

# %% [markdown]
# The model correctly classifies the unseen document with 'x'% probability to the X category.
